# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = sns.load_dataset('titanic')
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
df.shape
# Out:
# (891, 15)

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df['age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: age, dtype: float64

# %%
sns.distplot(df['fare'], kde = True)
# Out:
# <ipython-input-46-35a012a9f560>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['fare'], kde = True)
# <Axes: xlabel='fare', ylabel='Density'>

# %%
sns.distplot(df['fare'], kde = True)
# Out:
# <ipython-input-47-35a012a9f560>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['fare'], kde = True)
# <Axes: xlabel='fare', ylabel='Density'>

# %%
sns.histplot(df['embark_town'])
# Out:
# <Axes: xlabel='embark_town', ylabel='Count'>

# %%
sns.distplot(df['age'],kde = False)
# Out:
# <ipython-input-49-af7b31ada581>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'],kde = False)
# <Axes: xlabel='age'>

# %%
sns.catplot(x ="sex", hue ="survived",
kind ="count", data = df)

# %%
sns.violinplot(x ="sex", y ="age", hue ="survived",
data = df, split = True)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
df['age_grp'] =  pd.cut(df['age'], 8)
sns.barplot(y='survived', x='age_grp', data=df , estimator=np.std)
# Out:
# <Axes: xlabel='age_grp', ylabel='survived'>

# %%
sns.countplot(x='sex', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
df['Fare_Range'] = pd.qcut(df['fare'], 4)

# Barplot - Shows approximate values based
# on the height of bars.
sns.barplot(x ='Fare_Range', y ='survived',
data = df)
# Out:
# <Axes: xlabel='Fare_Range', ylabel='survived'>

# %%
sns.scatterplot(data=df, y="fare", x="age")
# Out:
# <Axes: xlabel='age', ylabel='fare'>
